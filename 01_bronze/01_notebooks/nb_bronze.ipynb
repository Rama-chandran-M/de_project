# %%
data = spark.read.csv("s3://aws-demo-bucket090/source_data/customer.csv", header=True, inferSchema=True)
data.printSchema()
data.write.mode("overwrite").saveAsTable("01_bronze_catalog.raw_schema.customer")
